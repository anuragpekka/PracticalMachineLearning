# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.metrics import  accuracy_score,log_loss, r2_score, roc_auc_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import VotingClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.preprocessing import OneHotEncoder


import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'..\Datasets\Cases\human-resources-analytics\HR_comma_sep.csv')
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.10             0.77               6                   247
# 3                0.92             0.85               5                   259
# 4                0.89             1.00               5                   224
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   5              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2     low
# 3     low
# 4     low

# %%
X = df.drop(columns=['salary'], axis=1)
y = df['salary']

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.10             0.77               6                   247
# 3                0.92             0.85               5                   259
# 4                0.89             1.00               5                   224
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   5              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2     low
# 3     low
# 4     low

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14995 entries, 0 to 14994
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14995 non-null  float64
#  1   last_evaluation        14995 non-null  float64
#  2   number_project         14995 non-null  int64
#  3   average_montly_hours   14995 non-null  int64
#  4   time_spend_company     14995 non-null  int64
#  5   Work_accident          14995 non-null  int64
#  6   left                   14995 non-null  int64
#  7   promotion_last_5years  14995 non-null  int64
#  8   Department             14995 non-null  object
#  9   salary                 14995 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24, stratify=y)

# %% [markdown]
# **GridSearchCV**

# %%
ohe = OneHotEncoder(
    sparse_output=False, 
    drop='first'
).set_output(transform='pandas')


ct = make_column_transformer(
    ('passthrough', make_column_selector(dtype_exclude=[
        'object',
        'category',
    ])),
    (ohe, make_column_selector(dtype_include=[
        'object',
        'category',
    ])),
    verbose_feature_names_out=False,
).set_output(transform='pandas')

# %%
dtc = DecisionTreeClassifier(random_state=24)
lr = LogisticRegression(random_state=24)
nb = GaussianNB()
vote = VotingClassifier([('DT', dtc), ('LR', lr), ('NB', nb)], voting='soft')


params = { 
    # 'DT__criterion': ['absolute_error'],
    # 'DT__criterion': ['absolute_error', 'friedman_mse','squared_error', 'poisson'],
    'VT__LR__C': np.linspace(0.001, 3, 5),
    'VT__DT__max_depth': [None, 2, 3],
    'VT__DT__min_samples_leaf':  [2, 10, 20],
    'VT__DT__min_samples_split':  [1, 10, 20],
}

# %%
pipe = Pipeline([
    ('CT', ct),
    ('VT', vote),
])

kfold = StratifiedKFold(n_splits=5, random_state=24, shuffle=True)

gcv = GridSearchCV(
    estimator=pipe,
    param_grid=params,
    cv=kfold,
    verbose=2,
)

# %%
gcv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.5s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.5s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.5s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   1.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.5s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   1.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.2s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.7s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.4s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.5s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   1.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.5s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   1.3s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   1.1s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.5s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.6s
# [CV] END VT__DT__max_depth=None, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.6s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.1s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.5s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.5s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.3s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   1.1s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.2s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=2, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=0.75075; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=1.5005; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.6s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   1.3s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=10, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.6s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.4s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.001; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=0.75075; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=1.5005; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.6s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=2.25025; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=10, VT__DT__min_samples_split=20, VT__LR__C=3.0; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=0.001; total time=   0.0s
# ...
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=2.25025; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=1, VT__LR__C=3.0; total time=   0.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   1.0s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.001; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=0.75075; total time=   0.9s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=1.5005; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.7s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.8s
# [CV] END VT__DT__max_depth=2, VT__DT__min_samples_leaf=20, VT__DT__min_samples_split=10, VT__LR__C=2.25025; total time=   0.8s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 gcv.fit(X_train, y_train)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\model_selection\_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\model_selection\_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\model_selection\_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\model_selection\_validation.py:910, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     907 result["fit_error"] = None
#     909 fit_time = time.time() - start_time
# --> 910 test_scores = _score(
#     911     estimator, X_test, y_test, scorer, score_params_test, error_score
#     912 )
#     913 score_time = time.time() - start_time - fit_time
#     914 if return_train_score:
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\model_selection\_validation.py:971, in _score(estimator, X_test, y_test, scorer, score_params, error_score)
#     969         scores = scorer(estimator, X_test, **score_params)
#     970     else:
# --> 971         scores = scorer(estimator, X_test, y_test, **score_params)
#     972 except Exception:
#     973     if isinstance(scorer, _MultimetricScorer):
#     974         # If `_MultimetricScorer` raises exception, the `error_score`
#     975         # parameter is equal to "raise".
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\metrics\_scorer.py:455, in _PassthroughScorer.__call__(self, estimator, *args, **kwargs)
#     453 def __call__(self, estimator, *args, **kwargs):
#     454     """Method that wraps estimator.score"""
# --> 455     return estimator.score(*args, **kwargs)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\pipeline.py:1004, in Pipeline.score(self, X, y, sample_weight, **params)
#    1002     if sample_weight is not None:
#    1003         score_params["sample_weight"] = sample_weight
# -> 1004     return self.steps[-1][1].score(Xt, y, **score_params)
#    1006 # metadata routing is enabled.
#    1007 routed_params = process_routing(
#    1008     self, "score", sample_weight=sample_weight, **params
#    1009 )
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\base.py:764, in ClassifierMixin.score(self, X, y, sample_weight)
#     739 """
#     740 Return the mean accuracy on the given test data and labels.
#     741
#    (...)
#     760     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     761 """
#     762 from .metrics import accuracy_score
# --> 764 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\ensemble\_voting.py:440, in VotingClassifier.predict(self, X)
#     438 check_is_fitted(self)
#     439 if self.voting == "soft":
# --> 440     maj = np.argmax(self.predict_proba(X), axis=1)
#     442 else:  # 'hard' voting
#     443     predictions = self._predict(X)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\ensemble\_voting.py:481, in VotingClassifier.predict_proba(self, X)
#     467 """Compute probabilities of possible outcomes for samples in X.
#     468
#     469 Parameters
#    (...)
#     477     Weighted average probability for each class per sample.
#     478 """
#     479 check_is_fitted(self)
#     480 avg = np.average(
# --> 481     self._collect_probas(X), axis=0, weights=self._weights_not_none
#     482 )
#     483 return avg
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\ensemble\_voting.py:456, in VotingClassifier._collect_probas(self, X)
#     454 def _collect_probas(self, X):
#     455     """Collect results from clf.predict calls."""
# --> 456     return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\tree\_classes.py:1042, in DecisionTreeClassifier.predict_proba(self, X, check_input)
#    1018 """Predict class probabilities of the input samples X.
#    1019
#    1020 The predicted class probability is the fraction of samples of the same
#    (...)
#    1039     classes corresponds to that in the attribute :term:`classes_`.
#    1040 """
#    1041 check_is_fitted(self)
# -> 1042 X = self._validate_X_predict(X, check_input)
#    1043 proba = self.tree_.predict(X)
#    1045 if self.n_outputs_ == 1:
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\tree\_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     force_all_finite = True
# --> 489 X = self._validate_data(
#     490     X,
#     491     dtype=DTYPE,
#     492     accept_sparse="csr",
#     493     reset=False,
#     494     force_all_finite=force_all_finite,
#     495 )
#     496 if issparse(X) and (
#     497     X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     498 ):
#     499     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\utils\validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010         array = xp.astype(array, dtype, copy=False)
#    1011     else:
# -> 1012         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013 except ComplexWarning as complex_warning:
#    1014     raise ValueError(
#    1015         "Complex data not supported\n{}\n".format(array)
#    1016     ) from complex_warning
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\sklearn\utils\_array_api.py:745, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     743     array = numpy.array(array, order=order, dtype=dtype)
#     744 else:
# --> 745     array = numpy.asarray(array, order=order, dtype=dtype)
#     747 # At this point array is a NumPy ndarray. We convert it to an array
#     748 # container that is consistent with the input's namespace.
#     749 return xp.asarray(array)
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\pandas\core\generic.py:2152, in NDFrame.__array__(self, dtype, copy)
#    2149 def __array__(
#    2150     self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151 ) -> np.ndarray:
# -> 2152     values = self._values
#    2153     arr = np.asarray(values, dtype=dtype)
#    2154     if (
#    2155         astype_is_view(values.dtype, arr.dtype)
#    2156         and using_copy_on_write()
#    2157         and self._mgr.is_single_block
#    2158     ):
#    2159         # Check if both conversions can be done without a copy
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\pandas\core\frame.py:1127, in DataFrame._values(self)
#    1125 blocks = mgr.blocks
#    1126 if len(blocks) != 1:
# -> 1127     return ensure_wrapped_if_datetimelike(self.values)
#    1129 arr = blocks[0].values
#    1130 if arr.ndim == 1:
#    1131     # non-2D ExtensionArray
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\pandas\core\frame.py:12664, in DataFrame.values(self)
#   12590 @property
#   12591 def values(self) -> np.ndarray:
#   12592     """
#   12593     Return a Numpy representation of the DataFrame.
#   12594
#    (...)
#   12662            ['monkey', nan, None]], dtype=object)
#   12663     """
# > 12664     return self._mgr.as_array()
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\anaconda3\envs\py3_12_0\Lib\site-packages\pandas\core\internals\managers.py:1754, in BlockManager._interleave(self, dtype, na_value)
#    1752         arr = blk.get_values(dtype)
#    1753     result[rl.indexer] = arr
# -> 1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#    1757     raise AssertionError("Some items were not contained in blocks")
#
# KeyboardInterrupt:

# %%
print(gcv.best_score_)
print(gcv.best_params_)

best_model = gcv.best_estimator_
best_model

# %%
y_pred = best_model.predict(X_test)
print('Accuracy Score:', accuracy_score(y_test, y_pred))

# %%
y_pred_prob = best_model.predict_proba(X_test)[:, 1] #predict_proba works with only voting='soft'
print(roc_auc_score(y_test, y_pred_prob))
